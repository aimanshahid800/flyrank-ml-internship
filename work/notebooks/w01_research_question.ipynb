# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/aimanshahid800/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Lane 2: Refresh / Content Opportunity Scoring. This lane fits because the starter pipeline already builds a transparent baseline and a learned model for this exact problem, giving a strong foundation to extend over the next 7 weeks.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
lane_choice = "Lane 2: Refresh / Content Opportunity Scoring"
print("Chosen lane:", lane_choice)
# Out:
# Chosen lane: Lane 2: Refresh / Content Opportunity Scoring

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Question: Which content pages should be reviewed first for refresh, given limited reviewer capacity? Decision improved: prioritizing which pages a content reviewer looks at first. Action: reviewer refreshes, expands, or monitors a flagged page. Cost of a wrong call: reviewer time wasted on a page that wasn't actually declining, or a genuinely declining page missed entirely.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Decision: prioritize review queue")
print("Action: refresh / expand / monitor")
# Out:
# Decision: prioritize review queue
# Action: refresh / expand / monitor

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# This shows an evidence-backed prioritization opportunity, not a guarantee that refreshing a page will cause recovery that would need a causal experiment. Claims here are observed and directional, not proof of Google's algorithm.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Claims: observed, directional, decision-support only")
# Out:
# Claims: observed, directional, decision-support only

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This shows an evidence-backed prioritization opportunity, not a guarantee that refreshing a page will cause recovery — that would need a causal experiment. Claims here are observed and directional, not proof of Google's algorithm.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Claims: observed, directional, decision-support only")
# Out:
# Claims: observed, directional, decision-support only

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
